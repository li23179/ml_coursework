# %% [markdown]
# Import the package for the Clustering Task

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

from sklearn.metrics import (
    adjusted_rand_score,
    normalized_mutual_info_score,
    silhouette_score,
)

# %% [markdown]
# 1. Load the MNIST dataset

# %%
# use fetch_openml, return as np.array 
mnist = fetch_openml("mnist_784", version=1, as_frame=False)
X = mnist.data.astype(np.float32)
y = mnist.target.astype(int)

print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
# Out:
# X shape: (70000, 784)
# y shape: (70000,)

# %% [markdown]
# 2. Visualise sampled images and labels and show a grid plot with one row per class and five images per class.

# %%
num_classes = 10 #0-9
images_per_class = 5 # each row contain 5 image

# create a grid plot with one row per class (0-9) 
# and each row contain 5 image in this class
fig, axes = plt.subplots(num_classes, images_per_class, figsize=(10, 20))

for num in range(num_classes):
    # find the first 5 indices that match the current number
    # np.where return a tuple so we need to extract the first element
    indices = np.where(y==num)[0][:images_per_class]

    for i, index in enumerate(indices):
        # need to reshape the image since original shape is 28*28
        img = X[index].reshape(28,28)
        ax = axes[num, i]
        ax.imshow(img)
        ax.axis("off")

        # label the row on the first image
        if i == 0:
            ax.text(
                -2, 14,           
                f"Digit {num}",       
                fontsize=36,
                color="black",
                ha="right",
                va="center",
            )

plt.suptitle("MNIST class images", x=0.625, y=1.0, fontsize=36)
plt.tight_layout()
plt.savefig("clustering_images/true_grid_cluster.png")
plt.show()

# %% [markdown]
# 3. Apply PCA to reduce 784 dimension to 50 to make training comoputationally feasible

# %%
pca = PCA(n_components=50)
pca.fit(X)
X_reduced = pca.transform(X)
print(f"X_reduced shape: {X_reduced.shape}")
# Out:
# X_reduced shape: (70000, 50)

# %% [markdown]
# 4. Create a helper function for evaluating the model using the metrics of Adjusted Rand Index (ARI), Normalised Mutual Information (NMI) and Silhouette Score (SS)

# %%
# Return the score of Adjusted Rand Index, Normalised Mutual Information, Silhouette Score
def evaluate_score(X_reduced, y, y_pred):
    ari = adjusted_rand_score(y, y_pred)
    nmi = normalized_mutual_info_score(y, y_pred)
    ss = silhouette_score(X_reduced, y_pred)

    return ari, nmi, ss

# %% [markdown]
# 5. Build a K-Mean Model with different hyperparameters

# %%
# Hyperparameter for K-Means: number of clusters and iterations for K-Means
n_clusters_params = [5, 8, 10, 12]
n_init_params = [10, 20, 30]

# use for generating the clustering results for K-Means
k_means_results = []
print("========== START K-MEANS HYPERPARAMETERS SELECTION ==========")
for K in n_clusters_params:
    for n_init in n_init_params:

        print(f"Running K-Means: number of clusters: {K}, number of initialisation: {n_init}")
        # initialise KMeans with different hyperparameters
        k_means = KMeans(
            n_clusters=K,
            n_init=n_init,
            random_state=42,
        )
        k_means.fit(X_reduced)
        y_pred = k_means.predict(X_reduced)
        ari, nmi, ss = evaluate_score(X_reduced, y, y_pred)
        # store the model result
        k_means_results.append({
            "model": "K-Means",
            "n_clusters": K,
            "n_init": n_init,
            "ari": ari,
            "nmi": nmi,
            "ss": ss,
        })

print("========== FINISH K-MEANS HYPERPARAMETERS SELECTION ==========")
# Out:
# ========== START K-MEANS HYPERPARAMETERS SELECTION ==========
# Running K-Means: number of clusters: 5, number of initialisation: 10
# Running K-Means: number of clusters: 5, number of initialisation: 20
# Running K-Means: number of clusters: 5, number of initialisation: 30
# Running K-Means: number of clusters: 8, number of initialisation: 10
# Running K-Means: number of clusters: 8, number of initialisation: 20
# Running K-Means: number of clusters: 8, number of initialisation: 30
# Running K-Means: number of clusters: 10, number of initialisation: 10
# Running K-Means: number of clusters: 10, number of initialisation: 20
# Running K-Means: number of clusters: 10, number of initialisation: 30
# Running K-Means: number of clusters: 12, number of initialisation: 10
# Running K-Means: number of clusters: 12, number of initialisation: 20
# Running K-Means: number of clusters: 12, number of initialisation: 30
# ========== FINISH K-MEANS HYPERPARAMETERS SELECTION ==========

# %% [markdown]
# 6. Build a GMM with different hyperparameters

# %%
# Hyperparameter for GMM: number of components and covariance matrix
n_components_params = [5, 8, 10, 12]
cov_type_params = ["full", "tied", "spherical", "diag"]

# use for generating the clustering results for GMM
gmm_results = []
print("========== START GMM HYPERPARAMETERS SELECTION ==========")
for n_components in n_components_params:
    for cov_type in cov_type_params:
        print(f"Running GMM: number of components={n_components}, covariance matrix type: {cov_type}")
        # initialise GMM with different hyperparameters
        gmm = GaussianMixture(
            n_components=n_components,
            covariance_type=cov_type,
            random_state=42,
        )
    
        gmm.fit(X_reduced)
        y_pred = gmm.predict(X_reduced)
        # evaluate the model with the helper function
        ari, nmi, ss = evaluate_score(X_reduced, y, y_pred)
        # store the model result
        gmm_results.append({
            "model": "GMM",
            "n_components": n_components,
            "cov_type": cov_type,
            "ari": ari,
            "nmi": nmi,
            "ss": ss
        })

print("========== FINISH GMM HYPERPARAMETERS SELECTION ==========")
# Out:
# ========== START GMM HYPERPARAMETERS SELECTION ==========
# Running GMM: number of components=5, covariance matrix type: full
# Running GMM: number of components=5, covariance matrix type: tied
# Running GMM: number of components=5, covariance matrix type: spherical
# Running GMM: number of components=5, covariance matrix type: diag
# Running GMM: number of components=8, covariance matrix type: full
# Running GMM: number of components=8, covariance matrix type: tied
# Running GMM: number of components=8, covariance matrix type: spherical
# Running GMM: number of components=8, covariance matrix type: diag
# Running GMM: number of components=10, covariance matrix type: full
# Running GMM: number of components=10, covariance matrix type: tied
# Running GMM: number of components=10, covariance matrix type: spherical
# Running GMM: number of components=10, covariance matrix type: diag
# Running GMM: number of components=12, covariance matrix type: full
# Running GMM: number of components=12, covariance matrix type: tied
# Running GMM: number of components=12, covariance matrix type: spherical
# Running GMM: number of components=12, covariance matrix type: diag
# ========== FINISH GMM HYPERPARAMETERS SELECTION ==========

# %% [markdown]
# 7. Visualise clustering results, using the best-performing model and configuration.

# %%
# Convert the K-Means and GMM results into panda data frame
k_means_df = pd.DataFrame(k_means_results)
gmm_df = pd.DataFrame(gmm_results)

# Concatenate two clustering results
results_df = pd.concat([k_means_df, gmm_df], ignore_index=True)
results_df = results_df.fillna("N/A")
results_df = results_df.round(3)
# find the best-performing model for each metric
best_ari_row = results_df.sort_values("ari", ascending=False).iloc[0]
best_nmi_row = results_df.sort_values("nmi", ascending=False).iloc[0]
best_ss_row = results_df.sort_values("ss", ascending=False).iloc[0]

# Combine all 3 metrics with weighted scores
# I think the importance of ARI > NMI > SS

w_ari = 0.5
w_nmi = 0.3
w_ss = 1 - w_ari - w_nmi

results_df["combined_score"] = w_ari * results_df["ari"] + w_nmi * results_df["nmi"] + w_ss * results_df["ss"]
best_combined_row = results_df.sort_values("combined_score", ascending=False).iloc[0]

print("========== MODEL SELECTION SUMMARY ==========")

print("Best Adjusted Random Index (ARI) model:")
print(best_ari_row)
print("==================================================")
print("Best Normalised Mutual Information (NMI) model:")
print(best_nmi_row)
print("==================================================")
print("Best Silhouette Score (SS) model:")
print(best_ss_row)
print("==================================================")
print("Best Combined Score model:")
print(best_combined_row)
print("==================================================")
# Out:
# ========== MODEL SELECTION SUMMARY ==========
# Best Adjusted Random Index (ARI) model:
# model             GMM
# n_clusters        N/A
# n_init            N/A
# ari             0.448
# nmi             0.616
# ss              0.045
# n_components     10.0
# cov_type         full
# Name: 20, dtype: object
# ==================================================
# Best Normalised Mutual Information (NMI) model:
# model             GMM
# n_clusters        N/A
# n_init            N/A
# ari             0.448
# nmi             0.616
# ss              0.045
# n_components     10.0
# cov_type         full
# Name: 20, dtype: object
# ==================================================
# Best Silhouette Score (SS) model:
# model           K-Means
# n_clusters          8.0
# n_init             10.0
# ari               0.396
# nmi               0.505
# ss                0.098
# n_components        N/A
# cov_type            N/A
# Name: 3, dtype: object
# ==================================================
# Best Combined Score model:
# model                GMM
# n_clusters           N/A
# n_init               N/A
# ari                0.448
# nmi                0.616
# ss                 0.045
# n_components        10.0
# cov_type            full
# combined_score    0.4178
# Name: 20, dtype: object
# ==================================================

# %% [markdown]
# 8. Show a grid plot with one row per cluster and five images per cluster with the best model

# %%
# create a helper plot function for both K-Means and GMM clusters
def plot_clusters_grid(X, cluster_labels, title):
    # find the unique clustering labels (i.e. [0,...,9] if K = 10 or n_component = 10 depending on the model)
    unique_cluster = np.unique(cluster_labels)
    n_clusters = len(np.unique(cluster_labels))
    # Create a subplots for each label
    fig, axes = plt.subplots(n_clusters, 5, figsize=(10, n_clusters*2))

    for row, cluster_id in enumerate(unique_cluster):
        # find the first 5 indices of images in the current cluster
        indices = np.where(cluster_labels == cluster_id)[0][:5]

        for col, index in enumerate(indices):
            # reshape the image to 28*28
            img = X[index].reshape(28, 28)
            ax = axes[row, col]
            ax.imshow(img)
            ax.axis("off")

            # label the corresponding cluster on each row on the first image
            if col == 0:
                ax.text(
                    -2, 14,            
                    f"Cluster: {cluster_id}",       
                    fontsize=36,
                    color="black",
                    ha="right",
                    va="center",
                )

    plt.suptitle(title, x=0.65, y=1.0, fontsize=36)
    plt.tight_layout()
    plt.savefig("clustering_images/best_model_grid_cluster.png")
    plt.show()

# Return best model and labels used for ploting the clusters images could be K-Means or GMM 
def refit_model(df_row, X_reduced):
    if df_row["model"] == "K-Means":
        model = KMeans(
            n_clusters=int(df_row["n_clusters"]),
            n_init=int(df_row["n_init"]),
            random_state=42,
        )    
        model.fit(X_reduced)
        labels = model.predict(X_reduced)
        return model, labels
    elif df_row["model"] == "GMM":
        model = GaussianMixture(
            n_components=int(df_row["n_components"]),
            covariance_type=df_row["cov_type"],
            random_state=42
        )
        model.fit(X_reduced)
        labels = model.predict(X_reduced)
        return model, labels
    
model, labels = refit_model(best_combined_row, X_reduced)
plot_clusters_grid(X, labels, title=f"Best model Clusters: ({best_combined_row['model']})")

# %% [markdown]
# 9. Results discussions, Which clustering method worked better for this
# dataset? Discussion on hyperparameter selection.

# %% [markdown]
# The Gaussian Mixture Model (GMM) with **10** components and **full** covariance worked better for this dataset.
# If we look at the MNIST digit distribution, we can notice there are many digits have similar or overlap shape (e.g. digits 3, 5, 8 have the curved structure, especially the lower loop).
#
# This suggest the **spherical cluster** (e.g. K-Means or spherical covariance matrix) may not be suitable for this clustering task, as it assumes all features are **independent** and with **equal variance**.
#
# For the selection of the number of components in GMM, it is also intuitively reasonable that the optimal value is **10**, since the MNIST dataset contains ten digit classes **(0–9)**.
#
# The **full covariance matrix** performed best because it provides the **maximum flexibility** during clustering. Each Gaussian component learns a completely new covariance matrix, which captures all **pairwise correlations** between PCA-reduced features. Other type of covariance matrices have different restrictions so it is hard to capture the complex handwritten digits structure.
